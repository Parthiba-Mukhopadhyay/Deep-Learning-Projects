# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
# Importing tensorflow and keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Softmax
from tensorflow.keras import optimizers

# %%
#Loading the dataset

housing_df=pd.read_csv("/content/housing.csv")

# %%
housing_df.shape
# Out:
# (20640, 10)

# %%
# Displaying the data

housing_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Checking for the null values

housing_df.isna().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms         True
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool

# %%
#Count of the null values in each columns

housing_df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# We can drop the null values as their count is less than 5 %

housing_df.dropna(inplace=True)
housing_df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
housing_df.shape
# Out:
# (20433, 10)

# %%
# Dividing the dataset into independant and dependant variables
X=pd.DataFrame(columns=['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','ocean_proximity'],data=housing_df)
y=pd.DataFrame(columns=['median_house_value'],data=housing_df)

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income ocean_proximity
# 0       322.0       126.0         8.3252        NEAR BAY
# 1      2401.0      1138.0         8.3014        NEAR BAY
# 2       496.0       177.0         7.2574        NEAR BAY
# 3       558.0       219.0         5.6431        NEAR BAY
# 4       565.0       259.0         3.8462        NEAR BAY

# %%
y.head()
# Out:
#    median_house_value
# 0            452600.0
# 1            358500.0
# 2            352100.0
# 3            341300.0
# 4            342200.0

# %%
#Creating the dummy values for ocean_proximity

X = pd.get_dummies(data = X, columns = ['ocean_proximity'] , prefix = ['ocean_proximity'] , drop_first = True)

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  ocean_proximity_INLAND  \
# 0       322.0       126.0         8.3252                       0
# 1      2401.0      1138.0         8.3014                       0
# 2       496.0       177.0         7.2574                       0
# 3       558.0       219.0         5.6431                       0
# 4       565.0       259.0         3.8462                       0
#
#    ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                       0                         1
# 1                       0                         1
# 2                       0                         1
# 3                       0                         1
# 4                       0                         1
#
#    ocean_proximity_NEAR OCEAN
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
#Dividing the training data into test and train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
X_train.shape
# Out:
# (14303, 12)

# %%
#Feature Standardization

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.14653761,  0.44712894, -0.68468262, ..., -0.01182583,
#         -0.35564951, -0.38507396],
#        [ 0.85461023, -0.83616485, -0.92275856, ..., -0.01182583,
#         -0.35564951, -0.38507396],
#        [ 0.58013858, -0.68629112,  0.42633841, ..., -0.01182583,
#         -0.35564951, -0.38507396],
#        ...,
#        [-1.34615336,  1.18713047, -0.44660669, ..., -0.01182583,
#          2.81175703, -0.38507396],
#        [ 0.84961983, -0.88300039, -1.55762772, ..., -0.01182583,
#         -0.35564951, -0.38507396],
#        [ 2.03234312, -1.38414066, -0.36724804, ..., -0.01182583,
#         -0.35564951, -0.38507396]])

# %%
model = Sequential()

#Input Layer
model.add(Dense(X.shape[1], activation='relu', input_dim = X.shape[1]))

#Hidden Layer
model.add(Dense(512,kernel_initializer='normal', activation='relu'))
model.add(Dense(512,kernel_initializer='normal', activation='relu'))
model.add(Dense(256,kernel_initializer='normal', activation='relu'))
model.add(Dense(128,kernel_initializer='normal', activation='relu'))
model.add(Dense(64,kernel_initializer='normal', activation='relu'))
model.add(Dense(32,kernel_initializer='normal', activation='relu'))
#Output Layer
model.add(Dense(1,kernel_initializer='normal', activation = 'relu'))

# %%
X.shape[1]
# Out:
# 12

# %%
#Compile the network

model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 12)                156
#
#  dense_21 (Dense)            (None, 512)               6656
#
#  dense_22 (Dense)            (None, 512)               262656
#
#  dense_23 (Dense)            (None, 256)               131328
#
#  dense_24 (Dense)            (None, 128)               32896
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dense_26 (Dense)            (None, 32)                2080
#
#  dense_27 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 444061 (1.69 MB)
# Trainable params: 444061 (1.69 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train.to_numpy(), batch_size = 32, epochs = 40, verbose = 1)
# Out:
# Epoch 1/40
# 447/447 [==============================] - 11s 24ms/step - loss: 3734501376.0000 - mse: 3734501376.0000 - mae: 42956.8242
# Epoch 2/40
# 447/447 [==============================] - 8s 19ms/step - loss: 3691924736.0000 - mse: 3691924736.0000 - mae: 42719.7812
# Epoch 3/40
# 447/447 [==============================] - 6s 14ms/step - loss: 3672869888.0000 - mse: 3672869888.0000 - mae: 42714.1445
# Epoch 4/40
# 447/447 [==============================] - 5s 12ms/step - loss: 3650912000.0000 - mse: 3650912000.0000 - mae: 42458.8555
# Epoch 5/40
# 447/447 [==============================] - 6s 13ms/step - loss: 3639444480.0000 - mse: 3639444480.0000 - mae: 42418.3086
# Epoch 6/40
# 447/447 [==============================] - 6s 13ms/step - loss: 3625682432.0000 - mse: 3625682432.0000 - mae: 42308.5625
# Epoch 7/40
# 447/447 [==============================] - 5s 12ms/step - loss: 3569638400.0000 - mse: 3569638400.0000 - mae: 41972.6445
# Epoch 8/40
# 447/447 [==============================] - 6s 14ms/step - loss: 3585488384.0000 - mse: 3585488384.0000 - mae: 41998.0000
# Epoch 9/40
# 447/447 [==============================] - 5s 11ms/step - loss: 3572023552.0000 - mse: 3572023552.0000 - mae: 41993.0859
# Epoch 10/40
# 447/447 [==============================] - 6s 13ms/step - loss: 3519541248.0000 - mse: 3519541248.0000 - mae: 41460.2461
# Epoch 11/40
# 447/447 [==============================] - 5s 12ms/step - loss: 3500619520.0000 - mse: 3500619520.0000 - mae: 41531.7188
# Epoch 12/40
# 447/447 [==============================] - 6s 14ms/step - loss: 3453726464.0000 - mse: 3453726464.0000 - mae: 40972.8320
# Epoch 13/40
# 447/447 [==============================] - 7s 15ms/step - loss: 3442060288.0000 - mse: 3442060288.0000 - mae: 41016.0938
# Epoch 14/40
# 447/447 [==============================] - 5s 12ms/step - loss: 3449770496.0000 - mse: 3449770496.0000 - mae: 41006.1133
# Epoch 15/40
# 447/447 [==============================] - 7s 15ms/step - loss: 3469518080.0000 - mse: 3469518080.0000 - mae: 41167.4492
# Epoch 16/40
# 447/447 [==============================] - 5s 11ms/step - loss: 3384057856.0000 - mse: 3384057856.0000 - mae: 40644.9414
# Epoch 17/40
# 447/447 [==============================] - 5s 12ms/step - loss: 3423025920.0000 - mse: 3423025920.0000 - mae: 40849.8945
# Epoch 18/40
# 447/447 [==============================] - 7s 15ms/step - loss: 3395707648.0000 - mse: 3395707648.0000 - mae: 40574.2148
# Epoch 19/40
# 447/447 [==============================] - 5s 11ms/step - loss: 3382212864.0000 - mse: 3382212864.0000 - mae: 40557.7383
# Epoch 20/40
# 447/447 [==============================] - 6s 14ms/step - loss: 3308203776.0000 - mse: 3308203776.0000 - mae: 40003.4141
# Epoch 21/40
# 447/447 [==============================] - 5s 11ms/step - loss: 3278490624.0000 - mse: 3278490624.0000 - mae: 39766.7266
# Epoch 22/40
# 447/447 [==============================] - 5s 12ms/step - loss: 3322439424.0000 - mse: 3322439424.0000 - mae: 40086.5820
# Epoch 23/40
# 447/447 [==============================] - 6s 14ms/step - loss: 3315917568.0000 - mse: 3315917568.0000 - mae: 40094.4805
# Epoch 24/40
# 447/447 [==============================] - 5s 11ms/step - loss: 3285673472.0000 - mse: 3285673472.0000 - mae: 39828.4180
# Epoch 25/40
# 447/447 [==============================] - 6s 14ms/step - loss: 3250958848.0000 - mse: 3250958848.0000 - mae: 39592.9961
# Epoch 26/40
# 447/447 [==============================] - 5s 11ms/step - loss: 3202915072.0000 - mse: 3202915072.0000 - mae: 39234.4961
# Epoch 27/40
# 447/447 [==============================] - 6s 13ms/step - loss: 3167552512.0000 - mse: 3167552512.0000 - mae: 39046.1992
# Epoch 28/40
# 447/447 [==============================] - 6s 14ms/step - loss: 3146880512.0000 - mse: 3146880512.0000 - mae: 38768.3750
# Epoch 29/40
# 447/447 [==============================] - 5s 11ms/step - loss: 3140990208.0000 - mse: 3140990208.0000 - mae: 38638.1914
# Epoch 30/40
# 447/447 [==============================] - 6s 14ms/step - loss: 3104610560.0000 - mse: 3104610560.0000 - mae: 38387.1641
# Epoch 31/40
# 447/447 [==============================] - 5s 12ms/step - loss: 3094747904.0000 - mse: 3094747904.0000 - mae: 38406.3711
# Epoch 32/40
# 447/447 [==============================] - 6s 13ms/step - loss: 3061186816.0000 - mse: 3061186816.0000 - mae: 38165.0391
# Epoch 33/40
# 447/447 [==============================] - 6s 13ms/step - loss: 3044961792.0000 - mse: 3044961792.0000 - mae: 38125.0156
# Epoch 34/40
# 447/447 [==============================] - 5s 11ms/step - loss: 3054807808.0000 - mse: 3054807808.0000 - mae: 38022.4961
# Epoch 35/40
# 447/447 [==============================] - 6s 14ms/step - loss: 2994918912.0000 - mse: 2994918912.0000 - mae: 37665.3711
# Epoch 36/40
# 447/447 [==============================] - 5s 11ms/step - loss: 2957890048.0000 - mse: 2957890048.0000 - mae: 37390.7773
# Epoch 37/40
# 447/447 [==============================] - 5s 12ms/step - loss: 2968111616.0000 - mse: 2968111616.0000 - mae: 37577.5234
# Epoch 38/40
# 447/447 [==============================] - 6s 14ms/step - loss: 2919723264.0000 - mse: 2919723264.0000 - mae: 37153.2891
# Epoch 39/40
# 447/447 [==============================] - 5s 11ms/step - loss: 2925408512.0000 - mse: 2925408512.0000 - mae: 37233.9336
# Epoch 40/40
# 447/447 [==============================] - 6s 14ms/step - loss: 2919440896.0000 - mse: 2919440896.0000 - mae: 37044.5156

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 192/192 [==============================] - 1s 4ms/step
# array([[128128.695],
#        [183918.7  ],
#        [139713.3  ],
#        ...,
#        [114335.84 ],
#        [ 76685.35 ],
#        [198567.77 ]], dtype=float32)

# %%
y_test
# Out:
#        median_house_value
# 14185             98900.0
# 6125             153000.0
# 14095             91300.0
# 14359            345200.0
# 18004            344100.0
# ...                   ...
# 20450            280200.0
# 14681            264000.0
# 2639              76800.0
# 2935              42700.0
# 15781            193800.0
#
# [6130 rows x 1 columns]

# %%
model.evaluate(X_test, y_test)
# Out:
# 192/192 [==============================] - 1s 3ms/step - loss: 3029753856.0000 - mse: 3029753856.0000 - mae: 37748.9688
# [3029753856.0, 3029753856.0, 37748.96875]
